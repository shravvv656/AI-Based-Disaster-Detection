# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import rasterio
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from rasterio.plot import show
from tensorflow.keras import layers, models

# %%
# Load CSV data
csv_path = "s1_data.csv"  
df = pd.read_csv(csv_path)  
df = df.sample(frac=1/3, random_state=42)
df['geometry'] = df['geometry'].apply(eval) 

df.head()
# Out:
#                                                geometry  label        date  \
# 438   [[[-1.734035, 6.823852], [-1.734157, 6.777547]...      0  2019-01-22
# 2674  [[[146.85126, -19.369506], [146.851218, -19.41...      1  2019-02-12
# 1345  [[[31.463419, -19.287912], [31.462987, -19.334...      0  2019-02-28
# 1957  [[[48.74212, 30.914307], [48.743203, 30.868143...      0  2019-04-08
# 2148  [[[48.578587, 31.670664], [48.579784, 31.62451...      0  2019-03-02
#
#       tile_number                                     id  location_id  \
# 438            90  sen12floods_s1_labels_0090_2019_01_22           90
# 2674           79  sen12floods_s1_labels_0335_2019_02_12          335
# 1345          -75  sen12floods_s1_labels_0181_2019_02_28          181
# 1957          -22  sen12floods_s1_labels_0234_2019_04_08          234
# 2148           -2  sen12floods_s1_labels_0254_2019_03_02          254
#
#                                               image_dir
# 438   sen12flood/sen12floods_s1_source/sen12floods_s...
# 2674  sen12flood/sen12floods_s1_source/sen12floods_s...
# 1345  sen12flood/sen12floods_s1_source/sen12floods_s...
# 1957  sen12flood/sen12floods_s1_source/sen12floods_s...
# 2148  sen12flood/sen12floods_s1_source/sen12floods_s...

# %%
def load_tiff(image_dir):
    vv_path = os.path.join(image_dir, "VV.tif")
    vh_path = os.path.join(image_dir, "VH.tif")

    with rasterio.open(vv_path) as vv, rasterio.open(vh_path) as vh:
        vv_band = vv.read(1)  
        vh_band = vh.read(1)  

    # Stack VV and VH bands to create a 2-channel image
    img = np.stack([vv_band, vh_band], axis=-1)
    
    # Normalize to [0, 1]
    img = (img - img.min()) / (img.max() - img.min())

    return img

# Example usage
example_image = load_tiff(df['image_dir'].iloc[0])
print("Image shape:", example_image.shape)
# Out:
# Image shape: (519, 519, 2)

# %%
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
from rasterio.features import rasterize

# %%
image_size = (64, 64)  
batch_size = 8

def load_tiff(image_dir):
    """
    Load VV and VH Sentinel-1 images as a 2-channel NumPy array.
    """
    try:
        # Construct file paths for VV & VH images
        vv_path = os.path.join(image_dir, "VV.tif")
        vh_path = os.path.join(image_dir, "VH.tif")

        # Load VV band
        with rasterio.open(vv_path) as vv:
            vv_image = vv.read(1)  # Read first band (grayscale)

        # Load VH band
        with rasterio.open(vh_path) as vh:
            vh_image = vh.read(1)  # Read first band (grayscale)

        # Normalize the images (optional)
        vv_image = (vv_image - vv_image.min()) / (vv_image.max() - vv_image.min() + 1e-6)
        vh_image = (vh_image - vh_image.min()) / (vh_image.max() - vh_image.min() + 1e-6)

        print(f"Succesfully loaded {image_dir}")

        # Stack VV & VH as separate channels
        img = np.stack([vv_image, vh_image], axis=-1)  # Shape: (H, W, 2)
        
        return img

    except Exception as e:
        print(f"Error loading images from {image_dir}: {e}")
        return None

# %%
def create_mask(geometry, shape=(64, 64)):
    try:
        # Ensure `geometry` is properly structured
        if isinstance(geometry[0], list):  
            coordinates = geometry[0]  # Extract the first list
        else:
            coordinates = geometry  

        # Convert to Polygon
        polygon = Polygon(coordinates).simplify(0.0001, preserve_topology=True)

        # Rasterize (optimized with NumPy)
        mask = rasterize(
            [(polygon, 1)],  # List of tuples (geometry, value)
            out_shape=shape,
            fill=0,
            dtype=np.uint8
        )
        
        print(f"Created mask for {geometry}")
        return mask

    except Exception as e:
        print(f"Error creating mask from geometry {geometry}: {e}")
        return None

# %%
# Data Preprocessing
def preprocess_data(row):
    img = load_tiff(row['image_dir'])
    
    if img is None or np.isnan(img).any():
        print(f"Warning: Issue loading {row['image_dir']}, replacing with zeros.")
        img = np.zeros((*image_size, 2), dtype=np.float32)  # 2 channels (VV, VH)

    mask = create_mask(row['geometry'])
    
    if mask is None or np.isnan(mask).any():
        print(f"Warning: Mask issue at {row['geometry']}, replacing with zeros.")
        mask = np.zeros(image_size, dtype=np.uint8)

    # Resize Image (Keep 2 channels)
    img = cv2.resize(img, image_size)  # OpenCV handles multi-channel resizing
    
    # Resize Mask
    mask = cv2.resize(mask, image_size)

    return img, mask

# Process Entire Dataset
images, masks = zip(*df.apply(preprocess_data, axis=1))
images, masks = np.array(images), np.array(masks)

# Expand dimensions for model input (masks should be (H, W, 1))
masks = np.expand_dims(masks, axis=-1)
# Out:
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0090_2019_01_22
# Created mask for [[[-1.734035, 6.823852], [-1.734157, 6.777547], [-1.687835, 6.777424], [-1.687709, 6.823728], [-1.734035, 6.823852]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0335_2019_02_12
# Created mask for [[[146.85126, -19.369506], [146.851218, -19.415777], [146.899986, -19.41581], [146.900015, -19.369539], [146.85126, -19.369506]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0181_2019_02_28
# Created mask for [[[31.463419, -19.287912], [31.462987, -19.334166], [31.511714, -19.334571], [31.512133, -19.288315], [31.463419, -19.287912]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0234_2019_04_08
# Created mask for [[[48.74212, 30.914307], [48.743203, 30.868143], [48.796721, 30.869066], [48.795663, 30.915231], [48.74212, 30.914307]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0254_2019_03_02
# Created mask for [[[48.578587, 31.670664], [48.579784, 31.624511], [48.633724, 31.625523], [48.632554, 31.671677], [48.578587, 31.670664]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_51_2019_01_18
# Created mask for [[[146.656437, -19.276701], [146.65634, -19.322972], [146.70508, -19.323057], [146.705163, -19.276786], [146.656437, -19.276701]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0220_2019_03_25
# Created mask for [[[32.846447, -19.826235], [32.846403, -19.872504], [32.895309, -19.872539], [32.89534, -19.826271], [32.846447, -19.826235]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0079_2019_02_03
# Created mask for [[[32.525317, 0.350843], [32.525319, 0.304522], [32.57133, 0.304524], [32.571328, 0.350845], [32.525317, 0.350843]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_49_2019_01_09
# Created mask for [[[36.749196, -1.288329], [36.749155, -1.334615], [36.795145, -1.334657], [36.795185, -1.28837], [36.749196, -1.288329]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0267_2019_03_09
# Created mask for [[[48.634891, 31.579367], [48.636056, 31.533212], [48.689945, 31.534197], [48.688807, 31.580354], [48.634891, 31.579367]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0231_2019_03_25
# Created mask for [[[48.687468, 30.959523], [48.688579, 30.913361], [48.74212, 30.914307], [48.741034, 30.96047], [48.687468, 30.959523]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0250_2019_03_25
# Created mask for [[[48.750717, 30.544987], [48.75178, 30.498821], [48.805095, 30.49973], [48.804057, 30.545898], [48.750717, 30.544987]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0286_2019_03_08
# Created mask for [[[48.692214, 31.441882], [48.693345, 31.395723], [48.747157, 31.396681], [48.746053, 31.442841], [48.692214, 31.441882]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0217_2019_03_12
# Created mask for [[[32.944248, -19.780024], [32.944232, -19.826293], [32.993124, -19.826301], [32.993126, -19.780032], [32.944248, -19.780024]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0133_2018_12_20
# Created mask for [[[25.800227, -24.634794], [25.799785, -24.681025], [25.850383, -24.681421], [25.850806, -24.635189], [25.800227, -24.634794]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0123_2019_01_29
# Created mask for [[[32.557855, -25.863753], [32.557683, -25.909985], [32.608803, -25.910132], [32.608955, -25.863899], [32.557855, -25.863753]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0336_2019_03_07
# Created mask for [[[146.900015, -19.369539], [146.899986, -19.41581], [146.948755, -19.41583], [146.948769, -19.369559], [146.900015, -19.369539]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0123_2019_02_05
# Created mask for [[[32.557855, -25.863753], [32.557683, -25.909985], [32.608803, -25.910132], [32.608955, -25.863899], [32.557855, -25.863753]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0031_2018_12_30
# Created mask for [[[31.031204, -17.747646], [31.030698, -17.793897], [31.078979, -17.794377], [31.079473, -17.748125], [31.031204, -17.747646]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0216_2019_03_07
# Created mask for [[[32.89537, -19.780002], [32.89534, -19.826271], [32.944232, -19.826293], [32.944248, -19.780024], [32.89537, -19.780002]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0121_2019_02_03
# Created mask for [[[32.558027, -25.81752], [32.557855, -25.863753], [32.608955, -25.863899], [32.609107, -25.817666], [32.558027, -25.81752]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0280_2019_03_20
# Created mask for [[[48.691081, 31.48804], [48.692214, 31.441882], [48.746053, 31.442841], [48.744947, 31.489], [48.691081, 31.48804]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0273_2019_03_03
# Created mask for [[[48.636056, 31.533212], [48.637218, 31.487056], [48.691081, 31.48804], [48.689945, 31.534197], [48.636056, 31.533212]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0163_2019_03_21
# Created mask for [[[36.800584, -17.783497], [36.801563, -17.829673], [36.849773, -17.828728], [36.848782, -17.782554], [36.800584, -17.783497]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0193_2019_03_31
# Created mask for [[[32.590517, -20.016233], [32.590397, -20.062499], [32.639361, -20.062606], [32.639466, -20.016339], [32.590517, -20.016233]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0187_2019_03_24
# Created mask for [[[32.671732, -19.855279], [32.671636, -19.901546], [32.720551, -19.90163], [32.720632, -19.855362], [32.671732, -19.855279]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0210_2019_04_17
# Created mask for [[[32.846536, -19.733698], [32.846492, -19.779967], [32.89537, -19.780002], [32.8954, -19.733733], [32.846536, -19.733698]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0223_2019_04_06
# Created mask for [[[48.682996, 31.144165], [48.684118, 31.098005], [48.737761, 31.098958], [48.736666, 31.14512], [48.682996, 31.144165]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0274_2019_03_15
# Created mask for [[[48.689945, 31.534197], [48.691081, 31.48804], [48.744947, 31.489], [48.743837, 31.53516], [48.689945, 31.534197]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0100_2018_12_29
# Created mask for [[[-1.734277, 6.731243], [-1.734397, 6.684938], [-1.688083, 6.684817], [-1.687959, 6.731121], [-1.734277, 6.731243]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0116_2019_01_22
# Created mask for [[[32.609712, -25.632732], [32.609561, -25.678966], [32.660582, -25.679094], [32.660713, -25.632859], [32.609712, -25.632732]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0012_2019_02_02
# Created mask for [[[36.657265, -1.241963], [36.657223, -1.288246], [36.703209, -1.288288], [36.70325, -1.242004], [36.657265, -1.241963]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0125_2019_01_10
# Created mask for [[[32.557683, -25.909985], [32.55751, -25.956217], [32.60865, -25.956364], [32.608803, -25.910132], [32.557683, -25.909985]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0331_2019_01_30
# Created mask for [[[146.656243, -19.369242], [146.656146, -19.415512], [146.704914, -19.415598], [146.704997, -19.369328], [146.656243, -19.369242]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0025_2018_12_31
# Created mask for [[[30.033794, -1.947753], [30.033877, -1.994009], [30.079851, -1.993923], [30.079766, -1.947669], [30.033794, -1.947753]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0198_2019_03_13
# Created mask for [[[32.750177, -20.016982], [32.750104, -20.063249], [32.799069, -20.063311], [32.799128, -20.017044], [32.750177, -20.016982]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0272_2019_02_25
# Created mask for [[[48.582169, 31.532204], [48.583358, 31.48605], [48.637218, 31.487056], [48.636056, 31.533212], [48.582169, 31.532204]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0278_2019_03_09
# Created mask for [[[48.583358, 31.48605], [48.584544, 31.439896], [48.638378, 31.4409], [48.637218, 31.487056], [48.583358, 31.48605]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_57_2019_01_28
# Created mask for [[[-1.734515, 6.638634], [-1.734633, 6.592329], [-1.688329, 6.592209], [-1.688206, 6.638513], [-1.734515, 6.638634]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0079_2018_12_29
# Created mask for [[[32.525317, 0.350843], [32.525319, 0.304522], [32.57133, 0.304524], [32.571328, 0.350845], [32.525317, 0.350843]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0079_2019_02_07
# Created mask for [[[32.525317, 0.350843], [32.525319, 0.304522], [32.57133, 0.304524], [32.571328, 0.350845], [32.525317, 0.350843]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0120_2019_02_05
# Created mask for [[[32.609259, -25.771433], [32.609107, -25.817666], [32.660188, -25.817795], [32.66032, -25.771561], [32.609259, -25.771433]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0303_2019_02_06
# Created mask for [[[146.656629, -19.184159], [146.656533, -19.23043], [146.705246, -19.230515], [146.705328, -19.184244], [146.656629, -19.184159]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0154_2019_03_20
# Created mask for [[[34.908799, -19.679607], [34.909347, -19.72585], [34.958181, -19.725323], [34.957618, -19.679081], [34.908799, -19.679607]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0226_2019_04_12
# Created mask for [[[48.737761, 31.098958], [48.738855, 31.052796], [48.792475, 31.053725], [48.791408, 31.099889], [48.737761, 31.098958]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0307_2019_02_06
# Created mask for [[[146.851427, -19.18442], [146.851385, -19.230692], [146.900099, -19.230725], [146.900127, -19.184453], [146.851427, -19.18442]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_67_2019_03_02
# Created mask for [[[34.859977, -19.680119], [34.860512, -19.726364], [34.909347, -19.72585], [34.908799, -19.679607], [34.859977, -19.680119]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0230_2019_04_14
# Created mask for [[[48.739946, 31.006633], [48.741034, 30.96047], [48.794603, 30.961396], [48.79354, 31.007561], [48.739946, 31.006633]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_1_2019_03_30
# Created mask for [[[31.575614, -19.220605], [31.575214, -19.266862], [31.623924, -19.267236], [31.62431, -19.220977], [31.575614, -19.220605]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0233_2019_04_20
# Created mask for [[[48.688579, 30.913361], [48.689688, 30.867199], [48.743203, 30.868143], [48.74212, 30.914307], [48.688579, 30.913361]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0084_2019_01_22
# Created mask for [[[32.57133, 0.304524], [32.571332, 0.258203], [32.617343, 0.258205], [32.617342, 0.304526], [32.57133, 0.304524]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0132_2018_12_26
# Created mask for [[[25.90179, -24.589334], [25.901387, -24.635567], [25.951968, -24.635928], [25.952353, -24.589694], [25.90179, -24.589334]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0009_2019_02_02
# Created mask for [[[36.749275, -1.195757], [36.749236, -1.242043], [36.795224, -1.242082], [36.795262, -1.195795], [36.749275, -1.195757]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_16_2019_03_31
# Created mask for [[[32.701314, -19.970639], [32.701227, -20.016906], [32.750177, -20.016982], [32.75025, -19.970714], [32.701314, -19.970639]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0210_2019_02_16
# Created mask for [[[32.846536, -19.733698], [32.846492, -19.779967], [32.89537, -19.780002], [32.8954, -19.733733], [32.846536, -19.733698]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_32_2019_02_06
# Created mask for [[[146.851385, -19.230692], [146.851344, -19.276963], [146.900071, -19.276997], [146.900099, -19.230725], [146.851385, -19.230692]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_44_2019_04_08
# Created mask for [[[48.691898, 30.774874], [48.693, 30.728711], [48.746438, 30.72965], [48.745362, 30.775815], [48.691898, 30.774874]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0074_2018_12_28
# Created mask for [[[32.479303, 0.39716], [32.479305, 0.35084], [32.525317, 0.350843], [32.525314, 0.397163], [32.479303, 0.39716]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0321_2019_01_30
# Created mask for [[[146.851344, -19.276963], [146.851302, -19.323235], [146.900043, -19.323268], [146.900071, -19.276997], [146.851344, -19.276963]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0025_2019_01_20
# Created mask for [[[30.033794, -1.947753], [30.033877, -1.994009], [30.079851, -1.993923], [30.079766, -1.947669], [30.033794, -1.947753]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0124_2018_12_24
# Created mask for [[[32.608955, -25.863899], [32.608803, -25.910132], [32.659924, -25.910261], [32.660056, -25.864028], [32.608955, -25.863899]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0156_2019_04_01
# Created mask for [[[34.860512, -19.726364], [34.861048, -19.772609], [34.909898, -19.772094], [34.909347, -19.72585], [34.860512, -19.726364]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0150_2019_03_19
# Created mask for [[[34.713504, -19.681577], [34.713997, -19.727825], [34.762837, -19.727352], [34.76233, -19.681104], [34.713504, -19.681577]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0205_2019_02_28
# Created mask for [[[32.84658, -19.687428], [32.846536, -19.733698], [32.8954, -19.733733], [32.89543, -19.687464], [32.84658, -19.687428]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_32_2019_03_07
# Created mask for [[[146.851385, -19.230692], [146.851344, -19.276963], [146.900071, -19.276997], [146.900099, -19.230725], [146.851385, -19.230692]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0015_2019_01_04
# Created mask for [[[36.795224, -1.242082], [36.795185, -1.28837], [36.841175, -1.28841], [36.841213, -1.242121], [36.795224, -1.242082]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0313_2019_02_05
# Created mask for [[[146.802672, -19.230646], [146.802617, -19.276917], [146.851344, -19.276963], [146.851385, -19.230692], [146.802672, -19.230646]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_61_2019_03_31
# Created mask for [[[32.671636, -19.901546], [32.671541, -19.947814], [32.72047, -19.947897], [32.720551, -19.90163], [32.671636, -19.901546]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_56_2019_02_06
# Created mask for [[[146.900071, -19.276997], [146.900043, -19.323268], [146.948784, -19.323288], [146.948798, -19.277017], [146.900071, -19.276997]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0162_2019_03_26
# Created mask for [[[36.752383, -17.784428], [36.75335, -17.830607], [36.801563, -17.829673], [36.800584, -17.783497], [36.752383, -17.784428]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0254_2019_03_01
# Created mask for [[[48.578587, 31.670664], [48.579784, 31.624511], [48.633724, 31.625523], [48.632554, 31.671677], [48.578587, 31.670664]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0277_2019_02_25
# Created mask for [[[48.5295, 31.485022], [48.530713, 31.438869], [48.584544, 31.439896], [48.583358, 31.48605], [48.5295, 31.485022]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0122_2018_12_25
# Created mask for [[[32.609107, -25.817666], [32.608955, -25.863899], [32.660056, -25.864028], [32.660188, -25.817795], [32.609107, -25.817666]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0080_2019_01_22
# Created mask for [[[32.571328, 0.350845], [32.57133, 0.304524], [32.617342, 0.304526], [32.61734, 0.350847], [32.571328, 0.350845]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0010_2018_12_28
# Created mask for [[[36.795262, -1.195795], [36.795224, -1.242082], [36.841213, -1.242121], [36.84125, -1.195832], [36.795262, -1.195795]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0243_2019_04_06
# Created mask for [[[48.694098, 30.682547], [48.695195, 30.636384], [48.748582, 30.637319], [48.747512, 30.683485], [48.694098, 30.682547]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_35_2019_03_09
# Created mask for [[[48.795559, 31.62842], [48.796647, 31.58226], [48.85057, 31.583179], [48.849509, 31.629341], [48.795559, 31.62842]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_39_2018_12_28
# Created mask for [[[32.525319, 0.304522], [32.525321, 0.258201], [32.571332, 0.258203], [32.57133, 0.304524], [32.525319, 0.304522]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_63_2019_04_12
# Created mask for [[[48.746438, 30.72965], [48.747512, 30.683485], [48.800927, 30.684401], [48.799879, 30.730567], [48.746438, 30.72965]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0059_2019_01_22
# Created mask for [[[17.035642, -22.55142], [17.036322, -22.597644], [17.086103, -22.597005], [17.085407, -22.550782], [17.035642, -22.55142]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_27_2019_04_01
# Created mask for [[[48.738855, 31.052796], [48.739946, 31.006633], [48.79354, 31.007561], [48.792475, 31.053725], [48.738855, 31.052796]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0223_2019_04_20
# Created mask for [[[48.682996, 31.144165], [48.684118, 31.098005], [48.737761, 31.098958], [48.736666, 31.14512], [48.682996, 31.144165]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0156_2019_02_18
# Created mask for [[[34.860512, -19.726364], [34.861048, -19.772609], [34.909898, -19.772094], [34.909347, -19.72585], [34.860512, -19.726364]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0233_2019_03_15
# Created mask for [[[48.688579, 30.913361], [48.689688, 30.867199], [48.743203, 30.868143], [48.74212, 30.914307], [48.688579, 30.913361]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0282_2019_03_20
# Created mask for [[[48.798815, 31.489939], [48.799895, 31.443777], [48.853739, 31.444691], [48.852685, 31.490854], [48.798815, 31.489939]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0234_2019_04_06
# Created mask for [[[48.74212, 30.914307], [48.743203, 30.868143], [48.796721, 30.869066], [48.795663, 30.915231], [48.74212, 30.914307]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0278_2019_03_03
# Created mask for [[[48.583358, 31.48605], [48.584544, 31.439896], [48.638378, 31.4409], [48.637218, 31.487056], [48.583358, 31.48605]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0156_2019_04_07
# Created mask for [[[34.860512, -19.726364], [34.861048, -19.772609], [34.909898, -19.772094], [34.909347, -19.72585], [34.860512, -19.726364]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0121_2018_12_25
# Created mask for [[[32.558027, -25.81752], [32.557855, -25.863753], [32.608955, -25.863899], [32.609107, -25.817666], [32.558027, -25.81752]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_23_2019_05_04
# Created mask for [[[54.350453, 37.06133], [54.352055, 37.015226], [54.409551, 37.016495], [54.407983, 37.062602], [54.350453, 37.06133]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0012_2019_02_05
# Created mask for [[[36.657265, -1.241963], [36.657223, -1.288246], [36.703209, -1.288288], [36.70325, -1.242004], [36.657265, -1.241963]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0154_2019_02_06
# Created mask for [[[34.908799, -19.679607], [34.909347, -19.72585], [34.958181, -19.725323], [34.957618, -19.679081], [34.908799, -19.679607]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0076_2019_01_16
# Created mask for [[[32.571326, 0.397166], [32.571328, 0.350845], [32.61734, 0.350847], [32.617338, 0.397168], [32.571326, 0.397166]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_33_2019_05_16
# Created mask for [[[54.352055, 37.015226], [54.353654, 36.969121], [54.411115, 36.970389], [54.409551, 37.016495], [54.352055, 37.015226]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0006_2019_01_02
# Created mask for [[[18.681385, -33.896767], [18.680135, -33.942907], [18.735496, -33.943938], [18.736717, -33.897797], [18.681385, -33.896767]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0230_2019_04_01
# Created mask for [[[48.739946, 31.006633], [48.741034, 30.96047], [48.794603, 30.961396], [48.79354, 31.007561], [48.739946, 31.006633]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0178_2019_02_28
# Created mask for [[[31.624694, -19.174719], [31.62431, -19.220977], [31.673007, -19.221336], [31.673378, -19.175077], [31.624694, -19.174719]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0095_2018_12_29
# Created mask for [[[-1.734157, 6.777547], [-1.734277, 6.731243], [-1.687959, 6.731121], [-1.687835, 6.777424], [-1.734157, 6.777547]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_4_2019_02_06
# Created mask for [[[146.60793, -19.184062], [146.60782, -19.230332], [146.656533, -19.23043], [146.656629, -19.184159], [146.60793, -19.184062]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_2_2019_01_16
# Created mask for [[[-1.595591, 6.63826], [-1.595722, 6.591957], [-1.54942, 6.591825], [-1.549285, 6.638126], [-1.595591, 6.63826]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0208_2019_02_16
# Created mask for [[[32.748808, -19.733587], [32.748735, -19.779856], [32.797613, -19.779918], [32.797672, -19.733649], [32.748808, -19.733587]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0198_2019_03_19
# Created mask for [[[32.750177, -20.016982], [32.750104, -20.063249], [32.799069, -20.063311], [32.799128, -20.017044], [32.750177, -20.016982]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0150_2019_02_06
# Created mask for [[[34.713504, -19.681577], [34.713997, -19.727825], [34.762837, -19.727352], [34.76233, -19.681104], [34.713504, -19.681577]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0036_2019_01_11
# Created mask for [[[30.982418, -17.793405], [30.981898, -17.839655], [31.03019, -17.840149], [31.030698, -17.793897], [30.982418, -17.793405]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0160_2019_02_13
# Created mask for [[[36.751419, -17.738249], [36.752383, -17.784428], [36.800584, -17.783497], [36.799607, -17.73732], [36.751419, -17.738249]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0044_2018_12_30
# Created mask for [[[31.078483, -17.84063], [31.077986, -17.886882], [31.126293, -17.887353], [31.126778, -17.841099], [31.078483, -17.84063]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0091_2019_01_22
# Created mask for [[[-1.687709, 6.823728], [-1.687835, 6.777424], [-1.641514, 6.777297], [-1.641383, 6.8236], [-1.687709, 6.823728]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0186_2019_03_12
# Created mask for [[[32.622831, -19.855182], [32.622722, -19.901449], [32.671636, -19.901546], [32.671732, -19.855279], [32.622831, -19.855182]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_54_2019_03_15
# Created mask for [[[36.75335, -17.830607], [36.75432, -17.876786], [36.802546, -17.875849], [36.801563, -17.829673], [36.75335, -17.830607]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0221_2019_03_07
# Created mask for [[[32.89534, -19.826271], [32.895309, -19.872539], [32.944216, -19.872561], [32.944232, -19.826293], [32.89534, -19.826271]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0182_2019_04_05
# Created mask for [[[31.512133, -19.288315], [31.511714, -19.334571], [31.560443, -19.334962], [31.560848, -19.288705], [31.512133, -19.288315]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0166_2019_03_14
# Created mask for [[[36.75432, -17.876786], [36.755293, -17.922964], [36.803531, -17.922025], [36.802546, -17.875849], [36.75432, -17.876786]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0077_2019_01_04
# Created mask for [[[32.617338, 0.397168], [32.61734, 0.350847], [32.663352, 0.350849], [32.66335, 0.39717], [32.617338, 0.397168]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0222_2019_02_16
# Created mask for [[[32.944232, -19.826293], [32.944216, -19.872561], [32.993122, -19.87257], [32.993124, -19.826301], [32.944232, -19.826293]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0282_2019_03_15
# Created mask for [[[48.798815, 31.489939], [48.799895, 31.443777], [48.853739, 31.444691], [48.852685, 31.490854], [48.798815, 31.489939]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0266_2019_03_15
# Created mask for [[[48.580978, 31.578358], [48.582169, 31.532204], [48.636056, 31.533212], [48.634891, 31.579367], [48.580978, 31.578358]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0018_2019_01_16
# Created mask for [[[36.703209, -1.288288], [36.703167, -1.334573], [36.749155, -1.334615], [36.749196, -1.288329], [36.703209, -1.288288]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0165_2019_03_26
# Created mask for [[[36.801563, -17.829673], [36.802546, -17.875849], [36.850768, -17.874901], [36.849773, -17.828728], [36.801563, -17.829673]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0181_2019_02_16
# Created mask for [[[31.463419, -19.287912], [31.462987, -19.334166], [31.511714, -19.334571], [31.512133, -19.288315], [31.463419, -19.287912]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0021_2018_12_28
# Created mask for [[[36.841175, -1.28841], [36.841135, -1.334698], [36.887128, -1.334739], [36.887167, -1.288448], [36.841175, -1.28841]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0079_2019_01_10
# Created mask for [[[32.525317, 0.350843], [32.525319, 0.304522], [32.57133, 0.304524], [32.571328, 0.350845], [32.525317, 0.350843]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0231_2019_04_14
# Created mask for [[[48.687468, 30.959523], [48.688579, 30.913361], [48.74212, 30.914307], [48.741034, 30.96047], [48.687468, 30.959523]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0227_2019_04_14
# Created mask for [[[48.685237, 31.051845], [48.686353, 31.005684], [48.739946, 31.006633], [48.738855, 31.052796], [48.685237, 31.051845]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0305_2019_01_18
# Created mask for [[[146.754028, -19.184316], [146.753959, -19.230587], [146.802672, -19.230646], [146.802727, -19.184374], [146.754028, -19.184316]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0248_2019_04_09
# Created mask for [[[48.749651, 30.591154], [48.750717, 30.544987], [48.804057, 30.545898], [48.803016, 30.592066], [48.749651, 30.591154]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0253_2019_03_08
# Created mask for [[[48.524624, 31.669628], [48.525847, 31.623477], [48.579784, 31.624511], [48.578587, 31.670664], [48.524624, 31.669628]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0232_2019_04_20
# Created mask for [[[48.741034, 30.96047], [48.74212, 30.914307], [48.795663, 30.915231], [48.794603, 30.961396], [48.741034, 30.96047]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_5_2019_02_04
# Created mask for [[[31.62431, -19.220977], [31.623924, -19.267236], [31.672635, -19.267596], [31.673007, -19.221336], [31.62431, -19.220977]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0103_2019_02_09
# Created mask for [[[-1.595327, 6.730863], [-1.59546, 6.684562], [-1.549149, 6.684427], [-1.549012, 6.730728], [-1.595327, 6.730863]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_28_2018_12_23
# Created mask for [[[-1.641898, 6.638389], [-1.642025, 6.592086], [-1.595722, 6.591957], [-1.595591, 6.63826], [-1.641898, 6.638389]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0247_2019_03_25
# Created mask for [[[48.696288, 30.590219], [48.697379, 30.544055], [48.750717, 30.544987], [48.749651, 30.591154], [48.696288, 30.590219]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0033_2019_01_11
# Created mask for [[[31.127743, -17.748591], [31.127261, -17.794846], [31.175545, -17.795302], [31.176014, -17.749046], [31.127743, -17.748591]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0186_2019_02_16
# Created mask for [[[32.622831, -19.855182], [32.622722, -19.901449], [32.671636, -19.901546], [32.671732, -19.855279], [32.622831, -19.855182]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0125_2018_12_24
# Created mask for [[[32.557683, -25.909985], [32.55751, -25.956217], [32.60865, -25.956364], [32.608803, -25.910132], [32.557683, -25.909985]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_40_2019_03_13
# Created mask for [[[48.742726, 31.581319], [48.743837, 31.53516], [48.797732, 31.5361], [48.796647, 31.58226], [48.742726, 31.581319]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0230_2019_04_20
# Created mask for [[[48.739946, 31.006633], [48.741034, 30.96047], [48.794603, 30.961396], [48.79354, 31.007561], [48.739946, 31.006633]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0219_2019_03_12
# Created mask for [[[32.797555, -19.826187], [32.797496, -19.872455], [32.846403, -19.872504], [32.846447, -19.826235], [32.797555, -19.826187]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0074_2018_12_26
# Created mask for [[[32.479303, 0.39716], [32.479305, 0.35084], [32.525317, 0.350843], [32.525314, 0.397163], [32.479303, 0.39716]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0065_2019_01_28
# Created mask for [[[28.392615, -15.382186], [28.392923, -15.428461], [28.440629, -15.428157], [28.440311, -15.381882], [28.392615, -15.382186]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0135_2018_12_20
# Created mask for [[[25.901387, -24.635567], [25.900982, -24.6818], [25.951582, -24.682162], [25.951968, -24.635928], [25.901387, -24.635567]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0076_2019_01_26
# Created mask for [[[32.571326, 0.397166], [32.571328, 0.350845], [32.61734, 0.350847], [32.617338, 0.397168], [32.571326, 0.397166]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0200_2019_03_07
# Created mask for [[[32.629207, -20.150871], [32.629098, -20.197137], [32.678104, -20.197233], [32.678199, -20.150967], [32.629207, -20.150871]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0123_2019_01_17
# Created mask for [[[32.557855, -25.863753], [32.557683, -25.909985], [32.608803, -25.910132], [32.608955, -25.863899], [32.557855, -25.863753]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0207_2019_04_12
# Created mask for [[[32.94428, -19.687485], [32.944264, -19.733755], [32.993128, -19.733763], [32.99313, -19.687494], [32.94428, -19.687485]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0047_2018_12_30
# Created mask for [[[30.933073, -17.885398], [30.932537, -17.931646], [30.980852, -17.932154], [30.981376, -17.885905], [30.933073, -17.885398]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0162_2019_03_14
# Created mask for [[[36.752383, -17.784428], [36.75335, -17.830607], [36.801563, -17.829673], [36.800584, -17.783497], [36.752383, -17.784428]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0230_2019_04_12
# Created mask for [[[48.739946, 31.006633], [48.741034, 30.96047], [48.794603, 30.961396], [48.79354, 31.007561], [48.739946, 31.006633]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0285_2019_02_25
# Created mask for [[[48.638378, 31.4409], [48.639534, 31.394743], [48.693345, 31.395723], [48.692214, 31.441882], [48.638378, 31.4409]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0082_2019_01_14
# Created mask for [[[32.479308, 0.30452], [32.47931, 0.2582], [32.525321, 0.258201], [32.525319, 0.304522], [32.479308, 0.30452]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0320_2019_02_23
# Created mask for [[[146.802617, -19.276917], [146.802561, -19.323189], [146.851302, -19.323235], [146.851344, -19.276963], [146.802617, -19.276917]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_43_2019_03_19
# Created mask for [[[32.8954, -19.733733], [32.89537, -19.780002], [32.944248, -19.780024], [32.944264, -19.733755], [32.8954, -19.733733]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0158_2019_03_20
# Created mask for [[[34.861048, -19.772609], [34.861586, -19.818853], [34.910449, -19.818337], [34.909898, -19.772094], [34.861048, -19.772609]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0244_2019_03_13
# Created mask for [[[48.747512, 30.683485], [48.748582, 30.637319], [48.801973, 30.638233], [48.800927, 30.684401], [48.747512, 30.683485]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0066_2019_01_28
# Created mask for [[[28.440311, -15.381882], [28.440629, -15.428157], [28.488334, -15.427842], [28.488005, -15.381568], [28.440311, -15.381882]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0218_2019_03_13
# Created mask for [[[32.748663, -19.826124], [32.74859, -19.872393], [32.797496, -19.872455], [32.797555, -19.826187], [32.748663, -19.826124]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0090_2019_01_03
# Created mask for [[[-1.734035, 6.823852], [-1.734157, 6.777547], [-1.687835, 6.777424], [-1.687709, 6.823728], [-1.734035, 6.823852]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0022_2018_12_19
# Created mask for [[[30.033712, -1.901496], [30.033794, -1.947753], [30.079766, -1.947669], [30.079683, -1.901415], [30.033712, -1.901496]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0096_2018_12_23
# Created mask for [[[-1.687835, 6.777424], [-1.687959, 6.731121], [-1.641643, 6.730994], [-1.641514, 6.777297], [-1.687835, 6.777424]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0151_2019_03_26
# Created mask for [[[34.76233, -19.681104], [34.762837, -19.727352], [34.811675, -19.726864], [34.811154, -19.680618], [34.76233, -19.681104]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0248_2019_04_01
# Created mask for [[[48.749651, 30.591154], [48.750717, 30.544987], [48.804057, 30.545898], [48.803016, 30.592066], [48.749651, 30.591154]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0208_2019_04_17
# Created mask for [[[32.748808, -19.733587], [32.748735, -19.779856], [32.797613, -19.779918], [32.797672, -19.733649], [32.748808, -19.733587]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0156_2019_03_02
# Created mask for [[[34.860512, -19.726364], [34.861048, -19.772609], [34.909898, -19.772094], [34.909347, -19.72585], [34.860512, -19.726364]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0316_2019_03_07
# Created mask for [[[146.60771, -19.276603], [146.6076, -19.322873], [146.65634, -19.322972], [146.656437, -19.276701], [146.60771, -19.276603]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_9_2019_02_03
# Created mask for [[[32.558199, -25.771287], [32.558027, -25.81752], [32.609107, -25.817666], [32.609259, -25.771433], [32.558199, -25.771287]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0125_2019_02_05
# Created mask for [[[32.557683, -25.909985], [32.55751, -25.956217], [32.60865, -25.956364], [32.608803, -25.910132], [32.557683, -25.909985]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0192_2019_03_31
# Created mask for [[[32.639572, -19.970072], [32.639466, -20.016339], [32.688417, -20.016432], [32.688508, -19.970165], [32.639572, -19.970072]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0011_2019_01_21
# Created mask for [[[36.84125, -1.195832], [36.841213, -1.242121], [36.887204, -1.242158], [36.88724, -1.195868], [36.84125, -1.195832]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0310_2019_01_30
# Created mask for [[[146.656533, -19.23043], [146.656437, -19.276701], [146.705163, -19.276786], [146.705246, -19.230515], [146.656533, -19.23043]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0147_2019_04_19
# Created mask for [[[34.810635, -19.634372], [34.811154, -19.680618], [34.859977, -19.680119], [34.859444, -19.633874], [34.810635, -19.634372]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0015_2019_02_05
# Created mask for [[[36.795224, -1.242082], [36.795185, -1.28837], [36.841175, -1.28841], [36.841213, -1.242121], [36.795224, -1.242082]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_7_2018_12_29
# Created mask for [[[17.034965, -22.505195], [17.035642, -22.55142], [17.085407, -22.550782], [17.084713, -22.504559], [17.034965, -22.505195]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0192_2019_03_07
# Created mask for [[[32.639572, -19.970072], [32.639466, -20.016339], [32.688417, -20.016432], [32.688508, -19.970165], [32.639572, -19.970072]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0207_2019_04_17
# Created mask for [[[32.94428, -19.687485], [32.944264, -19.733755], [32.993128, -19.733763], [32.99313, -19.687494], [32.94428, -19.687485]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0157_2019_02_06
# Created mask for [[[34.909347, -19.72585], [34.909898, -19.772094], [34.958745, -19.771565], [34.958181, -19.725323], [34.909347, -19.72585]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0105_2019_01_21
# Created mask for [[[-1.734397, 6.684938], [-1.734515, 6.638634], [-1.688206, 6.638513], [-1.688083, 6.684817], [-1.734397, 6.684938]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0065_2019_02_09
# Created mask for [[[28.392615, -15.382186], [28.392923, -15.428461], [28.440629, -15.428157], [28.440311, -15.381882], [28.392615, -15.382186]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0191_2019_03_31
# Created mask for [[[32.590636, -19.969966], [32.590517, -20.016233], [32.639466, -20.016339], [32.639572, -19.970072], [32.590636, -19.969966]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0167_2019_03_15
# Created mask for [[[36.802546, -17.875849], [36.803531, -17.922025], [36.851766, -17.921075], [36.850768, -17.874901], [36.802546, -17.875849]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_13_2019_01_02
# Created mask for [[[18.516745, -33.847396], [18.515408, -33.89353], [18.570731, -33.894634], [18.572038, -33.848498], [18.516745, -33.847396]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0090_2018_12_28
# Created mask for [[[-1.734035, 6.823852], [-1.734157, 6.777547], [-1.687835, 6.777424], [-1.687709, 6.823728], [-1.734035, 6.823852]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0235_2019_04_20
# Created mask for [[[48.689688, 30.867199], [48.690794, 30.821037], [48.744284, 30.821979], [48.743203, 30.868143], [48.689688, 30.867199]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_54_2019_03_20
# Created mask for [[[36.75335, -17.830607], [36.75432, -17.876786], [36.802546, -17.875849], [36.801563, -17.829673], [36.75335, -17.830607]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0077_2018_12_28
# Created mask for [[[32.617338, 0.397168], [32.61734, 0.350847], [32.663352, 0.350849], [32.66335, 0.39717], [32.617338, 0.397168]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0177_2019_03_24
# Created mask for [[[31.576012, -19.174347], [31.575614, -19.220605], [31.62431, -19.220977], [31.624694, -19.174719], [31.576012, -19.174347]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0310_2019_02_11
# Created mask for [[[146.656533, -19.23043], [146.656437, -19.276701], [146.705163, -19.276786], [146.705246, -19.230515], [146.656533, -19.23043]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_23_2019_05_05
# Created mask for [[[54.350453, 37.06133], [54.352055, 37.015226], [54.409551, 37.016495], [54.407983, 37.062602], [54.350453, 37.06133]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0201_2019_04_17
# Created mask for [[[32.580092, -20.197026], [32.579967, -20.243292], [32.628988, -20.243402], [32.629098, -20.197137], [32.580092, -20.197026]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_55_2019_02_09
# Created mask for [[[28.249522, -15.383035], [28.249798, -15.429313], [28.297507, -15.429039], [28.29722, -15.382762], [28.249522, -15.383035]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0227_2019_03_27
# Created mask for [[[48.685237, 31.051845], [48.686353, 31.005684], [48.739946, 31.006633], [48.738855, 31.052796], [48.685237, 31.051845]]]
# ...
# Created mask for [[[32.479305, 0.35084], [32.479308, 0.30452], [32.525319, 0.304522], [32.525317, 0.350843], [32.479305, 0.35084]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0063_2019_02_09
# Created mask for [[[28.29722, -15.382762], [28.297507, -15.429039], [28.345216, -15.428755], [28.344918, -15.382479], [28.29722, -15.382762]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0219_2019_02_23
# Created mask for [[[32.797555, -19.826187], [32.797496, -19.872455], [32.846403, -19.872504], [32.846447, -19.826235], [32.797555, -19.826187]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0168_2019_02_25
# Created mask for [[[36.755293, -17.922964], [36.756269, -17.969142], [36.804519, -17.968201], [36.803531, -17.922025], [36.755293, -17.922964]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0257_2019_03_20
# Created mask for [[[48.740494, 31.673635], [48.741611, 31.627477], [48.795559, 31.62842], [48.794468, 31.67458], [48.740494, 31.673635]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0276_2019_02_25
# Created mask for [[[48.797732, 31.5361], [48.798815, 31.489939], [48.852685, 31.490854], [48.851629, 31.537017], [48.797732, 31.5361]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0028_2019_01_23
# Created mask for [[[30.886408, -17.746139], [30.885865, -17.792386], [30.934141, -17.792902], [30.934672, -17.746653], [30.886408, -17.746139]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0225_2019_04_01
# Created mask for [[[48.684118, 31.098005], [48.685237, 31.051845], [48.738855, 31.052796], [48.737761, 31.098958], [48.684118, 31.098005]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0072_2019_01_28
# Created mask for [[[28.392923, -15.428461], [28.393232, -15.474737], [28.440949, -15.474431], [28.440629, -15.428157], [28.392923, -15.428461]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0276_2019_03_15
# Created mask for [[[48.797732, 31.5361], [48.798815, 31.489939], [48.852685, 31.490854], [48.851629, 31.537017], [48.797732, 31.5361]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0233_2019_03_20
# Created mask for [[[48.688579, 30.913361], [48.689688, 30.867199], [48.743203, 30.868143], [48.74212, 30.914307], [48.688579, 30.913361]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0139_2019_03_14
# Created mask for [[[34.290227, -15.487292], [34.290514, -15.533569], [34.338247, -15.533285], [34.337949, -15.487009], [34.290227, -15.487292]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0191_2019_03_24
# Created mask for [[[32.590636, -19.969966], [32.590517, -20.016233], [32.639466, -20.016339], [32.639572, -19.970072], [32.590636, -19.969966]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0162_2019_02_18
# Created mask for [[[36.752383, -17.784428], [36.75335, -17.830607], [36.801563, -17.829673], [36.800584, -17.783497], [36.752383, -17.784428]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0194_2019_02_23
# Created mask for [[[32.639466, -20.016339], [32.639361, -20.062606], [32.688325, -20.062699], [32.688417, -20.016432], [32.639466, -20.016339]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0188_2019_03_30
# Created mask for [[[32.573807, -19.901339], [32.573683, -19.947606], [32.622612, -19.947716], [32.622722, -19.901449], [32.573807, -19.901339]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_12_2019_04_02
# Created mask for [[[38.159593, -17.18523], [38.159384, -17.231507], [38.207539, -17.231702], [38.207736, -17.185425], [38.159593, -17.18523]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0214_2019_03_12
# Created mask for [[[32.797613, -19.779918], [32.797555, -19.826187], [32.846447, -19.826235], [32.846492, -19.779967], [32.797613, -19.779918]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0232_2019_03_13
# Created mask for [[[48.741034, 30.96047], [48.74212, 30.914307], [48.795663, 30.915231], [48.794603, 30.961396], [48.741034, 30.96047]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0334_2019_01_30
# Created mask for [[[146.802506, -19.369459], [146.80245, -19.41573], [146.851218, -19.415777], [146.85126, -19.369506], [146.802506, -19.369459]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0240_2019_04_13
# Created mask for [[[48.745362, 30.775815], [48.746438, 30.72965], [48.799879, 30.730567], [48.798829, 30.776734], [48.745362, 30.775815]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0115_2019_01_24
# Created mask for [[[32.609862, -25.586498], [32.609712, -25.632732], [32.660713, -25.632859], [32.660844, -25.586625], [32.609862, -25.586498]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0011_2019_01_04
# Created mask for [[[36.84125, -1.195832], [36.841213, -1.242121], [36.887204, -1.242158], [36.88724, -1.195868], [36.84125, -1.195832]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_35_2019_02_25
# Created mask for [[[48.795559, 31.62842], [48.796647, 31.58226], [48.85057, 31.583179], [48.849509, 31.629341], [48.795559, 31.62842]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0168_2019_02_06
# Created mask for [[[36.755293, -17.922964], [36.756269, -17.969142], [36.804519, -17.968201], [36.803531, -17.922025], [36.755293, -17.922964]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0182_2019_04_17
# Created mask for [[[31.512133, -19.288315], [31.511714, -19.334571], [31.560443, -19.334962], [31.560848, -19.288705], [31.512133, -19.288315]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0067_2019_02_09
# Created mask for [[[28.154377, -15.42983], [28.154633, -15.47611], [28.202355, -15.475856], [28.202088, -15.429577], [28.154377, -15.42983]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0157_2019_04_07
# Created mask for [[[34.909347, -19.72585], [34.909898, -19.772094], [34.958745, -19.771565], [34.958181, -19.725323], [34.909347, -19.72585]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0223_2019_03_20
# Created mask for [[[48.682996, 31.144165], [48.684118, 31.098005], [48.737761, 31.098958], [48.736666, 31.14512], [48.682996, 31.144165]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0155_2019_03_25
# Created mask for [[[34.811675, -19.726864], [34.812197, -19.77311], [34.861048, -19.772609], [34.860512, -19.726364], [34.811675, -19.726864]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0074_2019_01_14
# Created mask for [[[32.479303, 0.39716], [32.479305, 0.35084], [32.525317, 0.350843], [32.525314, 0.397163], [32.479303, 0.39716]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0157_2019_02_18
# Created mask for [[[34.909347, -19.72585], [34.909898, -19.772094], [34.958745, -19.771565], [34.958181, -19.725323], [34.909347, -19.72585]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0126_2019_02_05
# Created mask for [[[32.608803, -25.910132], [32.60865, -25.956364], [32.659791, -25.956493], [32.659924, -25.910261], [32.608803, -25.910132]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0323_2019_02_05
# Created mask for [[[146.6076, -19.322873], [146.607489, -19.369143], [146.656243, -19.369242], [146.65634, -19.322972], [146.6076, -19.322873]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0332_2019_01_18
# Created mask for [[[146.704997, -19.369328], [146.704914, -19.415598], [146.753682, -19.415671], [146.753751, -19.3694], [146.704997, -19.369328]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0219_2019_02_28
# Created mask for [[[32.797555, -19.826187], [32.797496, -19.872455], [32.846403, -19.872504], [32.846447, -19.826235], [32.797555, -19.826187]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0212_2019_03_13
# Created mask for [[[32.944264, -19.733755], [32.944248, -19.780024], [32.993126, -19.780032], [32.993128, -19.733763], [32.944264, -19.733755]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0081_2019_01_09
# Created mask for [[[32.61734, 0.350847], [32.617342, 0.304526], [32.663354, 0.304527], [32.663352, 0.350849], [32.61734, 0.350847]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0174_2019_03_09
# Created mask for [[[38.111229, -17.2313], [38.111007, -17.277576], [38.159174, -17.277783], [38.159384, -17.231507], [38.111229, -17.2313]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0121_2018_12_31
# Created mask for [[[32.558027, -25.81752], [32.557855, -25.863753], [32.608955, -25.863899], [32.609107, -25.817666], [32.558027, -25.81752]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0199_2019_03_12
# Created mask for [[[32.580215, -20.150761], [32.580092, -20.197026], [32.629098, -20.197137], [32.629207, -20.150871], [32.580215, -20.150761]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0095_2019_01_03
# Created mask for [[[-1.734157, 6.777547], [-1.734277, 6.731243], [-1.687959, 6.731121], [-1.687835, 6.777424], [-1.734157, 6.777547]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0236_2019_04_01
# Created mask for [[[48.743203, 30.868143], [48.744284, 30.821979], [48.797776, 30.8229], [48.796721, 30.869066], [48.743203, 30.868143]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0213_2019_03_07
# Created mask for [[[32.748735, -19.779856], [32.748663, -19.826124], [32.797555, -19.826187], [32.797613, -19.779918], [32.748735, -19.779856]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_43_2019_03_07
# Created mask for [[[32.8954, -19.733733], [32.89537, -19.780002], [32.944248, -19.780024], [32.944264, -19.733755], [32.8954, -19.733733]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0123_2019_01_22
# Created mask for [[[32.557855, -25.863753], [32.557683, -25.909985], [32.608803, -25.910132], [32.608955, -25.863899], [32.557855, -25.863753]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_27_2019_04_13
# Created mask for [[[48.738855, 31.052796], [48.739946, 31.006633], [48.79354, 31.007561], [48.792475, 31.053725], [48.738855, 31.052796]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0293_2019_04_10
# Created mask for [[[54.409551, 37.016495], [54.411115, 36.970389], [54.468579, 36.971629], [54.467049, 37.017737], [54.409551, 37.016495]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0336_2019_01_30
# Created mask for [[[146.900015, -19.369539], [146.899986, -19.41581], [146.948755, -19.41583], [146.948769, -19.369559], [146.900015, -19.369539]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0199_2019_03_30
# Created mask for [[[32.580215, -20.150761], [32.580092, -20.197026], [32.629098, -20.197137], [32.629207, -20.150871], [32.580215, -20.150761]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_1_2019_03_18
# Created mask for [[[31.575614, -19.220605], [31.575214, -19.266862], [31.623924, -19.267236], [31.62431, -19.220977], [31.575614, -19.220605]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0158_2019_03_14
# Created mask for [[[34.861048, -19.772609], [34.861586, -19.818853], [34.910449, -19.818337], [34.909898, -19.772094], [34.861048, -19.772609]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_40_2019_03_20
# Created mask for [[[48.742726, 31.581319], [48.743837, 31.53516], [48.797732, 31.5361], [48.796647, 31.58226], [48.742726, 31.581319]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0287_2019_03_09
# Created mask for [[[48.746053, 31.442841], [48.747157, 31.396681], [48.800973, 31.397615], [48.799895, 31.443777], [48.746053, 31.442841]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0191_2019_02_16
# Created mask for [[[32.590636, -19.969966], [32.590517, -20.016233], [32.639466, -20.016339], [32.639572, -19.970072], [32.590636, -19.969966]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0188_2019_03_19
# Created mask for [[[32.573807, -19.901339], [32.573683, -19.947606], [32.622612, -19.947716], [32.622722, -19.901449], [32.573807, -19.901339]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0108_2018_12_29
# Created mask for [[[-1.59546, 6.684562], [-1.595591, 6.63826], [-1.549285, 6.638126], [-1.549149, 6.684427], [-1.59546, 6.684562]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0081_2019_02_03
# Created mask for [[[32.61734, 0.350847], [32.617342, 0.304526], [32.663354, 0.304527], [32.663352, 0.350849], [32.61734, 0.350847]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0316_2019_01_30
# Created mask for [[[146.60771, -19.276603], [146.6076, -19.322873], [146.65634, -19.322972], [146.656437, -19.276701], [146.60771, -19.276603]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0212_2019_04_12
# Created mask for [[[32.944264, -19.733755], [32.944248, -19.780024], [32.993126, -19.780032], [32.993128, -19.733763], [32.944264, -19.733755]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0144_2019_03_19
# Created mask for [[[34.907706, -19.587119], [34.908251, -19.633363], [34.957057, -19.632839], [34.956498, -19.586596], [34.907706, -19.587119]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_29_2018_12_26
# Created mask for [[[32.479305, 0.35084], [32.479308, 0.30452], [32.525319, 0.304522], [32.525317, 0.350843], [32.479305, 0.35084]]]
# Succesfully loaded sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0184_2019_02_04
# Created mask for [[[31.511714, -19.334571], [31.511295, -19.380826], [31.560037, -19.381218], [31.560443, -19.334962], [31.511714, -19.334571]]]

# %%
from sklearn.model_selection import train_test_split

# Train-Test Split
X_train, X_val, y_train, y_val = train_test_split(images, masks, test_size=0.2, random_state=42)

# Print Dataset Shapes
print("Training shape:", X_train.shape, y_train.shape)
print("Validation shape:", X_val.shape, y_val.shape)

# Display Sample Image & Mask
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(X_train[0][:, :, 0], cmap="gray")
plt.title("VV Band")

plt.subplot(1, 2, 2)
plt.imshow(y_train[0].squeeze(), cmap="gray")
plt.title("Segmentation Mask")

plt.show()
# Out:
# Training shape: (888, 64, 64, 2) (888, 64, 64, 1)
# Validation shape: (222, 64, 64, 2) (222, 64, 64, 1)

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))\
                 .shuffle(1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))\
               .batch(batch_size).prefetch(tf.data.AUTOTUNE)
train_dataset = train_dataset.map(lambda x, y: (tf.cast(x, tf.float16), tf.cast(y, tf.float16)))
val_dataset = val_dataset.map(lambda x, y: (tf.cast(x, tf.float16), tf.cast(y, tf.float16)))

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.metrics import f1_score
from tqdm import tqdm
from tensorflow.keras import mixed_precision
import matplotlib.pyplot as plt

mixed_precision.set_global_policy('mixed_float16')

    def model():
        global train_dataset, val_dataset, X_val, y_val
    
        # Create the U-Net model
        def unet_model(input_shape=(64, 64, 2)):
            inputs = layers.Input(input_shape)
            
            # Encoder
            c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same', dtype='float16')(inputs)
            c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same', dtype='float16')(c1)
            p1 = layers.MaxPooling2D((2, 2))(c1)
            
            c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same', dtype='float16')(p1)
            c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same', dtype='float16')(c2)
            p2 = layers.MaxPooling2D((2, 2))(c2)
    
            c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same', dtype='float16')(p2)
            c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same', dtype='float16')(c3)
            p3 = layers.MaxPooling2D((2, 2))(c3)
            
            # Bottleneck
            c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same', dtype='float16')(p3)
            c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same', dtype='float16')(c4)
            
            # Decoder
            u5 = layers.UpSampling2D((2, 2))(c4)
            u5 = layers.Conv2D(256, (2, 2), activation='relu', padding='same', dtype='float16')(u5)
            c5 = layers.Concatenate()([u5, c3])
            c5 = layers.Conv2D(256, (3, 3), activation='relu', padding='same', dtype='float16')(c5)
            
            u6 = layers.UpSampling2D((2, 2))(c5)
            u6 = layers.Conv2D(128, (2, 2), activation='relu', padding='same', dtype='float16')(u6)
            c6 = layers.Concatenate()([u6, c2])
            c6 = layers.Conv2D(128, (3, 3), activation='relu', padding='same', dtype='float16')(c6)
    
            u7 = layers.UpSampling2D((2, 2))(c6)
            u7 = layers.Conv2D(64, (2, 2), activation='relu', padding='same', dtype='float16')(u7)
            c7 = layers.Concatenate()([u7, c1])
            c7 = layers.Conv2D(64, (3, 3), activation='relu', padding='same', dtype='float16')(c7)
            
            outputs = layers.Conv2D(1, (1, 1), activation='sigmoid', dtype='float32')(c7)
            return models.Model(inputs, outputs)
    
        # Initialize model, loss, optimizer
        model = unet_model()
        loss_fn = tf.keras.losses.BinaryCrossentropy()
        optimizer = mixed_precision.LossScaleOptimizer(tf.keras.optimizers.Adam(1e-4))
    
        # Track metrics
        train_acc_list, val_acc_list = [], []
        train_loss_list, val_loss_list = [], []
        f1_score_list = []
    
        # Training loop
        EPOCHS = 50
        for epoch in range(EPOCHS):
            print(f"\nEpoch {epoch+1}/{EPOCHS}")
            progbar = tqdm(train_dataset, desc="", leave=False)
    
            train_acc = tf.keras.metrics.BinaryAccuracy()
            train_loss_avg = tf.keras.metrics.Mean()
    
            # Training steps
            for step, (x_batch, y_batch) in enumerate(progbar):
                with tf.GradientTape() as tape:
                    logits = model(x_batch, training=True)
                    loss = loss_fn(y_batch, logits)
                    scaled_loss = optimizer.get_scaled_loss(loss)
    
                scaled_grads = tape.gradient(scaled_loss, model.trainable_variables)
                grads = optimizer.get_unscaled_gradients(scaled_grads)
                optimizer.apply_gradients(zip(grads, model.trainable_variables))
    
                train_loss_avg.update_state(loss)
                train_acc.update_state(y_batch, logits)
    
                progbar.set_description(f"{step+1}/{len(train_dataset)}")
    
            # Save train metrics
            train_loss_list.append(train_loss_avg.result().numpy())
            train_acc_list.append(train_acc.result().numpy())
    
            # Validation loop
            val_logits = []
            val_labels = []
            val_acc = tf.keras.metrics.BinaryAccuracy()
            val_loss_avg = tf.keras.metrics.Mean()
    
            for x_batch, y_batch in val_dataset:
                preds = model(x_batch, training=False)
                val_logits.append(preds.numpy().flatten())
                val_labels.append(y_batch.numpy().flatten())
                val_loss_avg.update_state(loss_fn(y_batch, preds))
                val_acc.update_state(y_batch, preds)
    
            y_pred_all = np.concatenate(val_logits)
            y_true_all = np.concatenate(val_labels)
            y_pred_binary = (y_pred_all > 0.5).astype(int)
    
            f1 = f1_score(y_true_all, y_pred_binary, average='binary')
            f1_score_list.append(f1)
            val_loss_list.append(val_loss_avg.result().numpy())
            val_acc_list.append(val_acc.result().numpy())
    
            print("Data Updated")
    
        return {
            'train_loss': train_loss_list,
            'train_accuracy': train_acc_list,
            'val_loss': val_loss_list,
            'val_accuracy': val_acc_list,
            'f1_score': f1_score_list
        }

# %%
metrics = model()
# Out:
# Epoch 1/50
# Data Updated
#
# Epoch 2/50
# Data Updated
#
# Epoch 3/50
# Data Updated
#
# Epoch 4/50
# Data Updated
#
# Epoch 5/50
# Data Updated
#
# Epoch 6/50
# Data Updated
#
# Epoch 7/50
# Data Updated
#
# Epoch 8/50
# Data Updated
#
# Epoch 9/50
# Data Updated
#
# Epoch 10/50
# Data Updated
#
# Epoch 11/50
# Data Updated
#
# Epoch 12/50
# Data Updated
#
# Epoch 13/50
# Data Updated
#
# Epoch 14/50
# Data Updated
#
# Epoch 15/50
# Data Updated
#
# Epoch 16/50
# Data Updated
#
# Epoch 17/50
# Data Updated
#
# Epoch 18/50
# Data Updated
#
# Epoch 19/50
# Data Updated
#
# Epoch 20/50
# Data Updated
#
# Epoch 21/50
# Data Updated
#
# Epoch 22/50
# Data Updated
#
# Epoch 23/50
# Data Updated
#
# Epoch 24/50
# Data Updated
#
# Epoch 25/50
# Data Updated
#
# Epoch 26/50
# Data Updated
#
# Epoch 27/50
# Data Updated
#
# Epoch 28/50
# Data Updated
#
# Epoch 29/50
# Data Updated
#
# Epoch 30/50
# Data Updated
#
# Epoch 31/50
# Data Updated
#
# Epoch 32/50
# Data Updated
#
# Epoch 33/50
# Data Updated
#
# Epoch 34/50
# Data Updated
#
# Epoch 35/50
# Data Updated
#
# Epoch 36/50
# Data Updated
#
# Epoch 37/50
# Data Updated
#
# Epoch 38/50
# Data Updated
#
# Epoch 39/50
# Data Updated
#
# Epoch 40/50
# Data Updated
#
# Epoch 41/50
# Data Updated
#
# Epoch 42/50
# Data Updated
#
# Epoch 43/50
# Data Updated
#
# Epoch 44/50
# Data Updated
#
# Epoch 45/50
# Data Updated
#
# Epoch 46/50
# Data Updated
#
# Epoch 47/50
# Data Updated
#
# Epoch 48/50
# Data Updated
#
# Epoch 49/50
# Data Updated
#
# Epoch 50/50
# Data Updated

# %%
m = metrics[0]
epochs = range(1, len(m['train_loss']) + 1)

# Train Loss
plt.figure(figsize=(10, 4))
plt.plot(epochs, m['train_loss'], label='Train Loss', color='blue')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train Loss')
plt.grid(True)
plt.show()

# Validation Loss
plt.figure(figsize=(10, 4))
plt.plot(epochs, m['val_loss'], label='Val Loss', color='orange')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation Loss')
plt.grid(True)
plt.show()

# Train Accuracy
plt.figure(figsize=(10, 4))
plt.plot(epochs, m['train_acc'], label='Train Accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Train Accuracy')
plt.grid(True)
plt.show()

# Validation Accuracy
plt.figure(figsize=(10, 4))
plt.plot(epochs, m['val_acc'], label='Val Accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy')
plt.grid(True)
plt.show()

# F1 Score
plt.figure(figsize=(10, 4))
plt.plot(epochs, m['f1_score'], label='F1 Score', color='purple')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.title('F1 Score')
plt.grid(True)
plt.show()

# %%
epoch_idx = 49 

print(f"Train Loss (Epoch 50): {m['train_loss'][epoch_idx]:.4f}")
print(f"Validation Loss (Epoch 50): {m['val_loss'][epoch_idx]:.4f}")
print(f"Training Accuracy (Epoch 50): {m['train_acc'][epoch_idx]:.4f}")
print(f"Validation Accuracy (Epoch 50): {m['val_acc'][epoch_idx]:.4f}")
print(f"F1 Score (Epoch 50): {m['f1_score'][epoch_idx]:.4f}")
# Out:
# Train Loss (Epoch 50): 0.2003
# Validation Loss (Epoch 50): 0.3965
# Training Accuracy (Epoch 50): 83.7485
# Validation Accuracy (Epoch 50): 83.3040
# F1 Score (Epoch 50): 86.0005
